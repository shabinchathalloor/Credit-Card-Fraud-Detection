# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# In this part of the series, we will train an Autoencoder Neural Network (implemented in Keras) in unsupervised (or semi-supervised) fashion for Anomaly Detection in credit card transaction data. The trained model will be evaluated on pre-labeled and anonymized dataset.
#   You can download dataset from Kaggle
# - [creditcard.csv]( https://www.kaggle.com/mlg-ulb/creditcardfraud)

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the data

# %% [markdown]
# The dataset we're going to use can be downloaded from Kaggle. It contains data about credit card transactions that occurred during a period of two days, with 492 frauds out of 284,807 transactions.
#
# All variables in the dataset are numerical. The data has been transformed using PCA transformation(s) due to privacy reasons. The two features that haven't been changed are Time and Amount. Time contains the seconds elapsed between each transaction and the first transaction in the dataset.

# %%
df = pd.read_csv("data/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# 31 columns, 2 of which are Time and Amount. The rest are output from the PCA transformations

# %%
df.isnull().values.any() #chech for missing value
# Out:
# False

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %% [markdown]
# How diffrent are the amount of money used in diffrent transaction classes?

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# Let's have a more graphical representation:

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins=bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins=bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of transactions')
plt.xlim(0,20000)
plt.yscale('log')
plt.show()

# %% [markdown]
# Let's check Do fraudulent transactions occur more often during certain time?

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# Doesn't seem like the time of transactions really matters

# %% [markdown]
# ## Autoencoders

# %% [markdown]
# Autoencoders can seem quite bizarre at first. The job of those models is to predict the input, given that same input.
#
# More specifically, let’s take a look at Autoencoder Neural Networks. This autoencoder tries to learn to approximate the following identity function:
#
# $$\textstyle f_{W,b}(x) \approx x$$
# While trying to do just that might sound trivial at first, it is important to note that we want to learn a compressed representation of the data, thus find structure. This can be done by limiting the number of hidden units in the model. Those kind of autoencoders are called undercomplete.

# %% [markdown]
# ## Reconstruction error

# %% [markdown]
# We optimize the parameters of our Autoencoder model in such way that a special kind of error - reconstruction error is minimized. In practice, the traditional squared error is often used:
#
# $$\textstyle L(x,x') = ||\, x - x'||^2$$

# %% [markdown]
# # Preparing the data

# %%
#Use the scikit's StandardScaler, The scalar removes the mean and scales the values to unit variance:
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1) #drop the Time column (not going to use it)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %% [markdown]
# Training our Autoencoder is gonna be a bit different from what we are used to. Let's say you have a dataset containing a lot of non fraudulent transactions at hand. You want to detect any anomaly on new transactions. We will create this situation by training our model on the normal transactions, only. Reserving the correct class on the test set will give us a way to evaluate the performance of our model. We will reserve 20% of our data for testing:

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (227451, 29)

# %% [markdown]
# ## Building the Model

# %% [markdown]
# Our Autoencoder uses 4 fully connected layers with 14, 7, 7 and 29 neurons respectively. The first two layers are used for our encoder, the last two go for the decoder. Additionally, L1 regularization will be used during training:

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
#train the model for 100 epochs with a batch size of 32 samples

nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='.\logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Train on 227451 samples, validate on 56962 samples
# Epoch 1/100
#   1280/227451 [..............................] - ETA: 7:48 - loss: 1.2575 - accuracy: 0.0625
# C:\Users\CHIT CHAT\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.122916). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 227451/227451 [==============================] - 21s 90us/step - loss: 0.8141 - accuracy: 0.5954 - val_loss: 0.7877 - val_accuracy: 0.6552
# Epoch 2/100
# 227451/227451 [==============================] - 20s 86us/step - loss: 0.7502 - accuracy: 0.6533 - val_loss: 0.7748 - val_accuracy: 0.6521
# Epoch 3/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7419 - accuracy: 0.6538 - val_loss: 0.7692 - val_accuracy: 0.6605
# Epoch 4/100
# 227451/227451 [==============================] - 19s 83us/step - loss: 0.7377 - accuracy: 0.6545 - val_loss: 0.7672 - val_accuracy: 0.6621
# Epoch 5/100
# 227451/227451 [==============================] - 18s 81us/step - loss: 0.7346 - accuracy: 0.6565 - val_loss: 0.7656 - val_accuracy: 0.6549
# Epoch 6/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7324 - accuracy: 0.6616 - val_loss: 0.7739 - val_accuracy: 0.6538
# Epoch 7/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7304 - accuracy: 0.6677 - val_loss: 0.7674 - val_accuracy: 0.6640
# Epoch 8/100
# 227451/227451 [==============================] - 18s 81us/step - loss: 0.7288 - accuracy: 0.6714 - val_loss: 0.7634 - val_accuracy: 0.6737
# Epoch 9/100
# 227451/227451 [==============================] - 19s 83us/step - loss: 0.7278 - accuracy: 0.6732 - val_loss: 0.7607 - val_accuracy: 0.6711
# Epoch 10/100
# 227451/227451 [==============================] - 20s 89us/step - loss: 0.7275 - accuracy: 0.6737 - val_loss: 0.7671 - val_accuracy: 0.6578
# Epoch 11/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7265 - accuracy: 0.6714 - val_loss: 0.7585 - val_accuracy: 0.6741
# Epoch 12/100
# 227451/227451 [==============================] - 20s 89us/step - loss: 0.7234 - accuracy: 0.6759 - val_loss: 0.7575 - val_accuracy: 0.6755
# Epoch 13/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7225 - accuracy: 0.6828 - val_loss: 0.7561 - val_accuracy: 0.6796
# Epoch 14/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7203 - accuracy: 0.6870 - val_loss: 0.7521 - val_accuracy: 0.6901
# Epoch 15/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.7193 - accuracy: 0.6898 - val_loss: 0.7535 - val_accuracy: 0.6896
# Epoch 16/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7187 - accuracy: 0.6915 - val_loss: 0.7543 - val_accuracy: 0.6908
# Epoch 17/100
# 227451/227451 [==============================] - 19s 86us/step - loss: 0.7179 - accuracy: 0.6937 - val_loss: 0.7507 - val_accuracy: 0.6926
# Epoch 18/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7174 - accuracy: 0.6955 - val_loss: 0.7496 - val_accuracy: 0.6949
# Epoch 19/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7174 - accuracy: 0.6972 - val_loss: 0.7487 - val_accuracy: 0.6975
# Epoch 20/100
# 227451/227451 [==============================] - 19s 82us/step - loss: 0.7170 - accuracy: 0.6985 - val_loss: 0.7520 - val_accuracy: 0.6905
# Epoch 21/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7171 - accuracy: 0.7001 - val_loss: 0.7482 - val_accuracy: 0.7028
# Epoch 22/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7160 - accuracy: 0.7008 - val_loss: 0.7492 - val_accuracy: 0.6958
# Epoch 23/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7163 - accuracy: 0.7003 - val_loss: 0.7490 - val_accuracy: 0.7013
# Epoch 24/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7165 - accuracy: 0.7012 - val_loss: 0.7483 - val_accuracy: 0.7011
# Epoch 25/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7159 - accuracy: 0.7004 - val_loss: 0.7570 - val_accuracy: 0.6994
# Epoch 26/100
# 227451/227451 [==============================] - 19s 82us/step - loss: 0.7159 - accuracy: 0.7009 - val_loss: 0.7493 - val_accuracy: 0.6943
# Epoch 27/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7150 - accuracy: 0.7017 - val_loss: 0.7479 - val_accuracy: 0.6999
# Epoch 28/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7152 - accuracy: 0.7012 - val_loss: 0.7484 - val_accuracy: 0.7013
# Epoch 29/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7149 - accuracy: 0.7016 - val_loss: 0.7566 - val_accuracy: 0.6973
# Epoch 30/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7156 - accuracy: 0.7015 - val_loss: 0.7519 - val_accuracy: 0.6934
# Epoch 31/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7150 - accuracy: 0.7018 - val_loss: 0.7482 - val_accuracy: 0.7000
# Epoch 32/100
# 227451/227451 [==============================] - 20s 86us/step - loss: 0.7145 - accuracy: 0.7021 - val_loss: 0.7488 - val_accuracy: 0.6982
# Epoch 33/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7148 - accuracy: 0.7016 - val_loss: 0.7482 - val_accuracy: 0.6996
# Epoch 34/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7154 - accuracy: 0.7023 - val_loss: 0.7470 - val_accuracy: 0.7070
# Epoch 35/100
# 227451/227451 [==============================] - 20s 90us/step - loss: 0.7147 - accuracy: 0.7019 - val_loss: 0.7482 - val_accuracy: 0.6915
# Epoch 36/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7142 - accuracy: 0.7018 - val_loss: 0.7502 - val_accuracy: 0.6968
# Epoch 37/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7145 - accuracy: 0.7023 - val_loss: 0.7491 - val_accuracy: 0.7064
# Epoch 38/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.7140 - accuracy: 0.7025 - val_loss: 0.7479 - val_accuracy: 0.7016
# Epoch 39/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7145 - accuracy: 0.7018 - val_loss: 0.7539 - val_accuracy: 0.7060
# Epoch 40/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7143 - accuracy: 0.7019 - val_loss: 0.7489 - val_accuracy: 0.7051
# Epoch 41/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7138 - accuracy: 0.7027 - val_loss: 0.7512 - val_accuracy: 0.6918
# Epoch 42/100
# 227451/227451 [==============================] - 18s 81us/step - loss: 0.7142 - accuracy: 0.7026 - val_loss: 0.7742 - val_accuracy: 0.6831
# Epoch 43/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.7148 - accuracy: 0.7029 - val_loss: 0.7490 - val_accuracy: 0.7032
# Epoch 44/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7136 - accuracy: 0.7036 - val_loss: 0.7455 - val_accuracy: 0.7033
# Epoch 45/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7144 - accuracy: 0.7031 - val_loss: 0.7466 - val_accuracy: 0.7079
# Epoch 46/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.7143 - accuracy: 0.7034 - val_loss: 0.7479 - val_accuracy: 0.6991
# Epoch 47/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7137 - accuracy: 0.7033 - val_loss: 0.7470 - val_accuracy: 0.7058
# Epoch 48/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7141 - accuracy: 0.7032 - val_loss: 0.7497 - val_accuracy: 0.7010
# Epoch 49/100
# 227451/227451 [==============================] - 19s 81us/step - loss: 0.7137 - accuracy: 0.7037 - val_loss: 0.7467 - val_accuracy: 0.7038
# Epoch 50/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7137 - accuracy: 0.7039 - val_loss: 0.7476 - val_accuracy: 0.7054
# Epoch 51/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7139 - accuracy: 0.7032 - val_loss: 0.7499 - val_accuracy: 0.7053
# Epoch 52/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7139 - accuracy: 0.7035 - val_loss: 0.7484 - val_accuracy: 0.7008
# Epoch 53/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7143 - accuracy: 0.7029 - val_loss: 0.7463 - val_accuracy: 0.7007
# Epoch 54/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7133 - accuracy: 0.7046 - val_loss: 0.7476 - val_accuracy: 0.7006
# Epoch 55/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7142 - accuracy: 0.7034 - val_loss: 0.7479 - val_accuracy: 0.6995
# Epoch 56/100
# 227451/227451 [==============================] - 20s 86us/step - loss: 0.7136 - accuracy: 0.7031 - val_loss: 0.7481 - val_accuracy: 0.7045
# Epoch 57/100
# 227451/227451 [==============================] - 18s 81us/step - loss: 0.7131 - accuracy: 0.7037 - val_loss: 0.7532 - val_accuracy: 0.7012
# Epoch 58/100
# 227451/227451 [==============================] - 23s 101us/step - loss: 0.7137 - accuracy: 0.7038 - val_loss: 0.7469 - val_accuracy: 0.7050
# Epoch 59/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.7138 - accuracy: 0.7047 - val_loss: 0.7500 - val_accuracy: 0.7015
# Epoch 60/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.7138 - accuracy: 0.7036 - val_loss: 0.7473 - val_accuracy: 0.7043
# Epoch 61/100
# 227451/227451 [==============================] - 21s 92us/step - loss: 0.7134 - accuracy: 0.7039 - val_loss: 0.7459 - val_accuracy: 0.7074
# Epoch 62/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7135 - accuracy: 0.7040 - val_loss: 0.7472 - val_accuracy: 0.7089
# Epoch 63/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.7130 - accuracy: 0.7039 - val_loss: 0.7459 - val_accuracy: 0.7077
# Epoch 64/100
# 227451/227451 [==============================] - 19s 85us/step - loss: 0.7132 - accuracy: 0.7055 - val_loss: 0.7471 - val_accuracy: 0.7026
# Epoch 65/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7136 - accuracy: 0.7048 - val_loss: 0.7465 - val_accuracy: 0.7029
# Epoch 66/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7134 - accuracy: 0.7048 - val_loss: 0.7518 - val_accuracy: 0.7006
# Epoch 67/100
# 227451/227451 [==============================] - 20s 87us/step - loss: 0.7134 - accuracy: 0.7044 - val_loss: 0.7461 - val_accuracy: 0.7084
# Epoch 68/100
# 227451/227451 [==============================] - 20s 87us/step - loss: 0.7136 - accuracy: 0.7038 - val_loss: 0.7468 - val_accuracy: 0.7041
# Epoch 69/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7137 - accuracy: 0.7044 - val_loss: 0.7464 - val_accuracy: 0.7103
# Epoch 70/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7132 - accuracy: 0.7046 - val_loss: 0.7485 - val_accuracy: 0.7048
# Epoch 71/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7136 - accuracy: 0.7047 - val_loss: 0.7455 - val_accuracy: 0.7069
# Epoch 72/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7133 - accuracy: 0.7049 - val_loss: 0.7485 - val_accuracy: 0.6902
# Epoch 73/100
# 227451/227451 [==============================] - 19s 84us/step - loss: 0.7141 - accuracy: 0.7039 - val_loss: 0.7499 - val_accuracy: 0.6977
# Epoch 74/100
# 227451/227451 [==============================] - 19s 85us/step - loss: 0.7133 - accuracy: 0.7052 - val_loss: 0.7470 - val_accuracy: 0.6997
# Epoch 75/100
# 227451/227451 [==============================] - 20s 87us/step - loss: 0.7135 - accuracy: 0.7052 - val_loss: 0.7492 - val_accuracy: 0.7013
# Epoch 76/100
# 227451/227451 [==============================] - 18s 80us/step - loss: 0.7136 - accuracy: 0.7045 - val_loss: 0.7454 - val_accuracy: 0.7113
# Epoch 77/100
# 227451/227451 [==============================] - 20s 88us/step - loss: 0.7139 - accuracy: 0.7041 - val_loss: 0.7467 - val_accuracy: 0.7063
# Epoch 78/100
# 227451/227451 [==============================] - 19s 83us/step - loss: 0.7131 - accuracy: 0.7053 - val_loss: 0.7556 - val_accuracy: 0.7000
# Epoch 79/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7134 - accuracy: 0.7048 - val_loss: 0.7483 - val_accuracy: 0.7046
# Epoch 80/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7130 - accuracy: 0.7050 - val_loss: 0.7501 - val_accuracy: 0.6990
# Epoch 81/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7134 - accuracy: 0.7052 - val_loss: 0.7468 - val_accuracy: 0.7125
# Epoch 82/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7133 - accuracy: 0.7052 - val_loss: 0.7475 - val_accuracy: 0.7092
# Epoch 83/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7137 - accuracy: 0.7050 - val_loss: 0.7463 - val_accuracy: 0.7036
# Epoch 84/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7129 - accuracy: 0.7054 - val_loss: 0.7487 - val_accuracy: 0.6975
# Epoch 85/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7133 - accuracy: 0.7054 - val_loss: 0.7457 - val_accuracy: 0.7091
# Epoch 86/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7136 - accuracy: 0.7060 - val_loss: 0.7473 - val_accuracy: 0.7013
# Epoch 87/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7134 - accuracy: 0.7048 - val_loss: 0.7475 - val_accuracy: 0.7066
# Epoch 88/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7133 - accuracy: 0.7048 - val_loss: 0.7480 - val_accuracy: 0.7032
# Epoch 89/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7136 - accuracy: 0.7052 - val_loss: 0.7487 - val_accuracy: 0.7076
# Epoch 90/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7131 - accuracy: 0.7058 - val_loss: 0.7485 - val_accuracy: 0.7001
# Epoch 91/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7136 - accuracy: 0.7061 - val_loss: 0.7495 - val_accuracy: 0.7027
# Epoch 92/100
# 227451/227451 [==============================] - 18s 77us/step - loss: 0.7140 - accuracy: 0.7051 - val_loss: 0.7455 - val_accuracy: 0.7076
# Epoch 93/100
# 227451/227451 [==============================] - 17s 77us/step - loss: 0.7132 - accuracy: 0.7051 - val_loss: 0.7506 - val_accuracy: 0.7019
# Epoch 94/100
# 227451/227451 [==============================] - 18s 78us/step - loss: 0.7129 - accuracy: 0.7062 - val_loss: 0.7489 - val_accuracy: 0.7064
# Epoch 95/100
# 227451/227451 [==============================] - 18s 79us/step - loss: 0.7135 - accuracy: 0.7064 - val_loss: 0.7479 - val_accuracy: 0.7075
# Epoch 96/100
# 227451/227451 [==============================] - 17s 74us/step - loss: 0.7129 - accuracy: 0.7069 - val_loss: 0.7472 - val_accuracy: 0.7046
# Epoch 97/100
# 227451/227451 [==============================] - 17s 75us/step - loss: 0.7125 - accuracy: 0.7105 - val_loss: 0.7442 - val_accuracy: 0.7077
# Epoch 98/100
# 227451/227451 [==============================] - 20s 89us/step - loss: 0.7118 - accuracy: 0.7121 - val_loss: 0.7431 - val_accuracy: 0.7130
# Epoch 99/100
# 227451/227451 [==============================] - 19s 85us/step - loss: 0.7116 - accuracy: 0.7130 - val_loss: 0.7430 - val_accuracy: 0.7173
# Epoch 100/100
# 227451/227451 [==============================] - 17s 76us/step - loss: 0.7111 - accuracy: 0.7135 - val_loss: 0.7490 - val_accuracy: 0.7134

# %%
autoencoder = load_model('model.h5')

# %% [markdown]
# ## Evaluation

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %% [markdown]
# The reconstruction error on our training and test data seems to converge nicely. Is it low enough? Let's have a closer look at the error distribution:

# %%
predictions = autoencoder.predict(X_test)

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.734432      0.001720
# std                3.369628      0.041443
# min                0.058144      0.000000
# 25%                0.249034      0.000000
# 50%                0.394374      0.000000
# 75%                0.621578      0.000000
# max              258.330226      1.000000

# %% [markdown]
# ## Reconstruction error without fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %% [markdown]
# ## Reconstruction error with fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %% [markdown]
# ROC curves are very useful tool for understanding the performance of binary classifiers. However, our case is a bit out of the ordinary. We have a very imbalanced dataset. Nonetheless, let's have a look at our ROC curve:

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %% [markdown]
# The ROC curve plots the true positive rate versus the false positive rate, over different threshold values. Basically, we want the blue line to be as close as possible to the upper left corner. While our results look pretty good, we have to keep in mind of the nature of our dataset. ROC doesn't look very useful for us. Onward...

# %% [markdown]
# ## Precision Vs Recall

# %% [markdown]
# Precision and recall are defined as follows:
#
# $$\text{Precision} = \frac{\text{true positives}}{\text{true positives} + \text{false positives}}$$
#
# Let's take an example from Information Retrieval in order to better understand what precision and recall are. Precision measures the relevancy of obtained results. Recall, on the other hand, measures how many relevant results are returned. Both values can take values between 0 and 1. You would love to have a system with both values being equal to 1.
#
# Let's return to our example from Information Retrieval. High recall but low precision means many results, most of which has low or no relevancy. When precision is high but recall is low we have the opposite - few returned results with very high relevancy. Ideally, you would want high precision and high recall - many results with that are highly relevant.

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='precision-Recall curve')
plt.title('Recall Vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# A high area under the curve represents both high recall and high precision, where high precision relates to a low false positive rate, and high recall relates to a low false negative rate. High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all positive results (high recall).

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# Here, we can see that the reconstruction error increases our precision rises as well

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# Here, we have the exact opposite situation. As the reconstruction error increases the recall decreases.

# %% [markdown]
# ## Prediction

# %% [markdown]
# In order to predict whether or not a new/unseen transaction is normal or fraudulent, we'll calculate the reconstruction error from the transaction data itself. If the error is larger than a predefined threshold, we'll mark it as a fraud (since our model should have a low error on normal transactions).

# %%
threshold = 2.9

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %% [markdown]
# ## conclusion

# %% [markdown]
# We've created a very simple Deep Autoencoder in Keras that can reconstruct what non fraudulent transactions looks like. we gave a lot of one-class examples (normal transactions) to a model and it learned (somewhat) how to discriminate whether or not new examples belong to that same class.

# %% [markdown]
# ## References

# %% [markdown]
# - [Github]( https://github.com/curiousily/Credit-Card-Fraud-Detection-using-Autoencoders-in-Keras/blob/master/fraud_detection.ipynb)
# - [Building auto encoders in Keras]( https://blog.keras.io/building-autoencoders-in-keras.html)
# - [Stanford tutorial on Autoencoders]( http://ufldl.stanford.edu/tutorial/unsupervised/Autoencoders/)
# - [Stacked Autoencoders in TensorFlow]( http://cmgreen.io/2016/01/04/tensorflow_deep_autoencoder.html)
